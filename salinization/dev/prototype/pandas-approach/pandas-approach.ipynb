# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

import pandas as pd

# Set Jupyter notebook display options
pd.options.display.max_rows = 8
pd.options.display.max_columns = 8

# Check version number
pd.__version__
# Out:
# '0.25.1'

# %%
excel = pd.ExcelFile('../../../dataset/bentre/003. Binh Dai(2002-2015.xls')
df = pd.read_excel(excel, sheet_name='2012')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 17 columns):
#         ĐÀI KHÍ TƯỢNG THỦY VĂN KHU VỰC NAM BỘ    69 non-null object
# Unnamed: 1                                             64 non-null float64
# Unnamed: 2                                             64 non-null float64
# Unnamed: 3                                             65 non-null object
# Unnamed: 4                                             64 non-null float64
# Unnamed: 5                                             64 non-null float64
# Unnamed: 6                                             64 non-null float64
# Unnamed: 7                                             64 non-null float64
# Unnamed: 8                                             65 non-null object
# Unnamed: 9                                             64 non-null float64
# Unnamed: 10                                            64 non-null float64
# Unnamed: 11                                            64 non-null float64
# Unnamed: 12                                            64 non-null float64
# Unnamed: 13                                            64 non-null object
# Unnamed: 14                                            65 non-null object
# Unnamed: 15                                            64 non-null object
# Unnamed: 16                                            5 non-null float64
# dtypes: float64(11), object(6)
# memory usage: 9.6+ KB

# %%
df.head(10)
# Out:
#            ĐÀI KHÍ TƯỢNG THỦY VĂN KHU VỰC NAM BỘ  Unnamed: 1  \
# 0           PHÒNG THÍ NGHIỆM PHÂN TÍCH MÔI TRƯỜNG ...          NaN
# 1           Số 8 Mạc Đĩnh Chi – Quận I – Tp Hồ ...          NaN
# 2           Tel: (08) 38290092  Fax: (08)38296091 ...          NaN
# 3                                                 NaN          NaN
# ..                                                ...          ...
# 6                                      Trạm: Bình Đại          NaN
# 7                                            Ngày/Giờ        1.000
# 8                                 2012-02-01 00:00:00        5.650
# 9                                 2012-02-02 00:00:00        8.575
#
#     Unnamed: 2           Unnamed: 3  ...  Unnamed: 13  Unnamed: 14  \
# 0          NaN                  NaN  ...          NaN          NaN
# 1          NaN                  NaN  ...          NaN          NaN
# 2          NaN                  NaN  ...          NaN          NaN
# 3          NaN                  NaN  ...          NaN          NaN
# ..         ...                  ...  ...          ...          ...
# 6          NaN  Sông/Kênh: Bình Đại  ...          NaN     Năm 2012
# 7        3.000                    5  ...           BQ          Max
# 8        2.200                1.225  ...       4.1125        11.25
# 9        5.575                  2.3  ...      6.54167       14.675
#
#     Unnamed: 15  Unnamed: 16
# 0           NaN          NaN
# 1           NaN          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# ..          ...          ...
# 6           NaN          NaN
# 7           Min          NaN
# 8         0.775          NaN
# 9         0.925          NaN
#
# [10 rows x 17 columns]

# %%
df.tail(10)
# Out:
#            ĐÀI KHÍ TƯỢNG THỦY VĂN KHU VỰC NAM BỘ  Unnamed: 1  \
# 61                                2012-06-07 00:00:00        3.275
# 62                                2012-06-12 00:00:00        2.475
# 63                                2012-06-13 00:00:00        3.800
# 64                                2012-06-14 00:00:00        5.350
# ..                                                ...          ...
# 67                                2012-06-25 00:00:00        0.600
# 68                                2012-06-27 00:00:00        1.325
# 69                                2012-06-28 00:00:00        3.025
# 70                                2012-06-29 00:00:00        5.925
#
#     Unnamed: 2 Unnamed: 3  ...  Unnamed: 13  Unnamed: 14  Unnamed: 15  \
# 61       7.325      13.65  ...      13.3875       21.125        3.275
# 62       1.925      1.525  ...      5.12917       13.075        1.525
# 63       2.625      1.825  ...      7.21042       17.025        1.825
# 64       4.025       3.05  ...      6.70208       15.925         3.05
# ..         ...        ...  ...          ...          ...          ...
# 67       0.300      5.325  ...      4.44792        12.05          0.3
# 68       0.800      3.075  ...       5.3125           14          0.8
# 69       2.175        2.1  ...        5.925        13.35          2.1
# 70       4.025      3.225  ...      7.38958        16.75        1.425
#
#     Unnamed: 16
# 61          NaN
# 62          NaN
# 63          NaN
# 64          NaN
# ..          ...
# 67          NaN
# 68          NaN
# 69          NaN
# 70       21.125
#
# [10 rows x 17 columns]

# %%
station = df.iloc[6][0]
station = station[station.find(':') + 1:].strip()
print(f'[{station}]')
# Out:
# [Bình Đại]

# %%
temp = df.drop(df[df.index < 7].index)
temp.head()
# Out:
#            ĐÀI KHÍ TƯỢNG THỦY VĂN KHU VỰC NAM BỘ  Unnamed: 1  \
# 7                                            Ngày/Giờ        1.000
# 8                                 2012-02-01 00:00:00        5.650
# 9                                 2012-02-02 00:00:00        8.575
# 10                                2012-02-03 00:00:00       10.975
# 11                                2012-02-09 00:00:00       12.350
#
#     Unnamed: 2 Unnamed: 3  ...  Unnamed: 13  Unnamed: 14  Unnamed: 15  \
# 7        3.000          5  ...           BQ          Max          Min
# 8        2.200      1.225  ...       4.1125        11.25        0.775
# 9        5.575        2.3  ...      6.54167       14.675        0.925
# 10       6.825        4.1  ...      9.13125       16.375        2.125
# 11      15.975       16.3  ...      10.6917         16.3          3.8
#
#     Unnamed: 16
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
#
# [5 rows x 17 columns]

# %%
temp.columns = temp.iloc[0]
temp = temp.drop([7])
temp.head()
# Out:
# 7              Ngày/Giờ     1.0     3.0       5  ...       BQ     Max    Min  \
# 8   2012-02-01 00:00:00   5.650   2.200   1.225  ...   4.1125   11.25  0.775
# 9   2012-02-02 00:00:00   8.575   5.575     2.3  ...  6.54167  14.675  0.925
# 10  2012-02-03 00:00:00  10.975   6.825     4.1  ...  9.13125  16.375  2.125
# 11  2012-02-09 00:00:00  12.350  15.975    16.3  ...  10.6917    16.3    3.8
# 12  2012-02-10 00:00:00   7.725  13.225  17.875  ...  10.8563  17.875    3.4
#
# 7   NaN
# 8   NaN
# 9   NaN
# 10  NaN
# 11  NaN
# 12  NaN
#
# [5 rows x 17 columns]

# %%
temp = temp.drop(['BQ'], axis=1)
temp.head()
# Out:
# 7              Ngày/Giờ     1.0     3.0       5  ...    23.0     Max    Min  \
# 8   2012-02-01 00:00:00   5.650   2.200   1.225  ...  10.900   11.25  0.775
# 9   2012-02-02 00:00:00   8.575   5.575     2.3  ...  14.075  14.675  0.925
# 10  2012-02-03 00:00:00  10.975   6.825     4.1  ...  15.500  16.375  2.125
# 11  2012-02-09 00:00:00  12.350  15.975    16.3  ...   7.325    16.3    3.8
# 12  2012-02-10 00:00:00   7.725  13.225  17.875  ...   6.025  17.875    3.4
#
# 7   NaN
# 8   NaN
# 9   NaN
# 10  NaN
# 11  NaN
# 12  NaN
#
# [5 rows x 16 columns]
